# %%
import pandas as pd
 #read the data
df=pd.read_csv('C:/Users/Eman/Desktop/data/survey_results_public.csv')
 #display the data
print(df)
 #shape show the matrix row*columns
print(df.shape)
 #show columns and rows and thier datatypes
print(df.info())
 #change the set system to show the whole columns
pd.set_option('display.max_columns',85)
 #sschema explain what columns mean
sc=pd.read_csv('C:/Users/Eman/Desktop/data/survey_results_schema.csv')
 #change the set system to show the whole rows
pd.set_option('display.max_rows',85)
 #show the first 5 rows instead of all rows
df.head()
 #show the first certain rows instead of all rows
df.head(12)
 #show the last 5 rows instead of all rows
df.tail()
 #show the last certain rows instead of all rows
df.tail(8)
print(df)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
print(df.columns)
print('\n')
print(df["Hobbyist"])
 #get info about this column 
print(df.Hobbyist.value_counts())
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
 # access the first row with a certain column(Hobbyist)
df.loc[0,"Hobbyist"]
# Out:
# 'Yes'

# %%
 #slicing from first row to 4 and 3 columns
df.loc[:4,"DatabaseWorkedWith":"WebFrameWorkedWith"]
# Out:
#                                  DatabaseWorkedWith  \
# 0                                            SQLite
# 1                                               NaN
# 2                                        PostgreSQL
# 3                                      MySQL;SQLite
# 4  Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                               DatabaseDesireNextYear  \
# 0                                              MySQL
# 1                                              MySQL
# 2                                         PostgreSQL
# 3                                       MySQL;SQLite
# 4  Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                   PlatformWorkedWith                 PlatformDesireNextYear  \
# 0                      MacOS;Windows                Android;Arduino;Windows
# 1                            Windows                                Windows
# 2                                NaN                                    NaN
# ...

# %%
 #changing the index
df.set_index('Respondent',inplace=True)
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
 # filtering data according to the salary
high_salary=(df['ConvertedComp'] > 70000)
df[high_salary]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 13                             I am a developer by profession      Yes
# 16                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88876                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
 #with certain columns
df.loc[high_salary,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries=['United States','India','United Kingdom','Canada','Germany']
filt=df["Country"].isin(countries)
df.loc[filt,"Country"]
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 8                 India
# 10                India
#               ...
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# 88377            Canada
# Name: Country, Length: 45008, dtype: object

# %%
filt=df['LanguageWorkedWith'].str.contains('python',na=False)
filt
# Out:
# Respondent
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
df.loc[filt]
# Out:
# Empty DataFrame
# ...

# %%
df.rename(columns={'ConvertedComp':'SalaryUSD'},inplace=True)
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df["SalaryUSD"]
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df.columns.value_counts()
# Out:
# MainBranch                1
# OpSys                     1
# Extraversion              1
# SocialMedia               1
# OffOn                     1
# ITperson                  1
# BetterLife                1
# BlockchainIs              1
# BlockchainOrg             1
# Containers                1
# DevEnviron                1
# Hobbyist                  1
# MiscTechDesireNextYear    1
# MiscTechWorkedWith        1
# WebFrameDesireNextYear    1
# WebFrameWorkedWith        1
# PlatformDesireNextYear    1
# PlatformWorkedWith        1
# DatabaseDesireNextYear    1
# DatabaseWorkedWith        1
# ScreenName                1
# SOVisit1st                1
# SOVisitFreq               1
# SOVisitTo                 1
# SurveyLength              1
# Dependents                1
# Ethnicity                 1
# Sexuality                 1
# Trans                     1
# Gender                    1
# Age                       1
# SONewContent              1
# WelcomeChange             1
# ...

# %%
 # data here is yes and no
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
 # here we convert data to be boolean
df['Hobbyist']=df['Hobbyist'].map({'Yes':True,"NO":False})

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code     True
# 2                      I am a student who is learning to code      NaN
# 3           I am not primarily a developer, but I write co...     True
# 4                              I am a developer by profession      NaN
# 5                              I am a developer by profession     True
# ...                                                       ...      ...
# 88377                                                     NaN     True
# 88601                                                     NaN      NaN
# 88802                                                     NaN      NaN
# 88816                                                     NaN      NaN
# 88863                                                     NaN     True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
 # can use replace too
df['Hobbyist']=df['Hobbyist'].replace({'Yes':True,"NO":False}) 
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code     True
# 2                      I am a student who is learning to code      NaN
# 3           I am not primarily a developer, but I write co...     True
# 4                              I am a developer by profession      NaN
# 5                              I am a developer by profession     True
# ...                                                       ...      ...
# 88377                                                     NaN     True
# 88601                                                     NaN      NaN
# 88802                                                     NaN      NaN
# 88816                                                     NaN      NaN
# 88863                                                     NaN     True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
 #showing the first 8 in column salary
df['SalaryUSD'].head(8)
# Out:
# Respondent
# 1         NaN
# 2         NaN
# 3      8820.0
# 4     61000.0
# 5         NaN
# 6    366420.0
# 7         NaN
# 8         NaN
# Name: SalaryUSD, dtype: float64

# %%
 #show every thing mathimatical
df.describe()
# Out:
#           CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %%
 #showing how much one answered the question
df.SalaryUSD.count()
# Out:
# 55823

# %%
 #replacing the values in this column to yas,no
df['Hobbyist']=df['Hobbyist'].replace({True:'Yes',False:'No'})

# %%
 # showing the first 7 in the column
df['Hobbyist'].head(7)
# Out:
# Respondent
# 1    Yes
# 2    NaN
# 3    Yes
# 4    NaN
# 5    Yes
# 6    Yes
# 7    NaN
# Name: Hobbyist, dtype: object

# %%
 # showing the value counts
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
 #in percentage
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
country_gro=df.groupby(['Country'])

# %%
country_gro['SocialMedia'].value_counts(normalize=True).loc['India']
# Out:
# SocialMedia
# WhatsApp                    0.342379
# YouTube                     0.208405
# LinkedIn                    0.109355
# Facebook                    0.096301
# Instagram                   0.094126
# Twitter                     0.062063
# Reddit                      0.054162
# I don't use social media    0.028627
# Snapchat                    0.002634
# Hello                       0.000573
# WeChat 微信                   0.000573
# VK ВКонта́кте               0.000458
# Youku Tudou 优酷              0.000229
# Weibo 新浪微博                  0.000115
# Name: SocialMedia, dtype: float64

# %%
 # finding the median
country_gro['SalaryUSD'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: SalaryUSD, Length: 179, dtype: float64

# %%
 # showing more than one function using agg
country_gro['SalaryUSD'].agg(['median','mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
 # # showing more than one function using agg in a specific column
country_gro['SalaryUSD'].agg(['median','mean']).loc["China"]
# Out:
# median    28464.000000
# mean      57430.421053
# Name: China, dtype: float64

# %%
 # the same using filter
filt=df["Country"] == "India" 
df.loc[filt]['SocialMedia'].value_counts(normalize=True)
# Out:
# WhatsApp                    0.342379
# YouTube                     0.208405
# LinkedIn                    0.109355
# Facebook                    0.096301
# Instagram                   0.094126
# Twitter                     0.062063
# Reddit                      0.054162
# I don't use social media    0.028627
# Snapchat                    0.002634
# Hello                       0.000573
# WeChat 微信                   0.000573
# VK ВКонта́кте               0.000458
# Youku Tudou 优酷              0.000229
# Weibo 新浪微博                  0.000115
# Name: SocialMedia, dtype: float64

# %% [markdown]
# using median instead of mean because mean influenced by outliersk

# %%
 # showing the median of salary column
df['SalaryUSD'].median()
# Out:
# 57287.0

# %%
 # showing the median
df.median()
# Out:
# C:\Users\Eman\AppData\Local\Temp\ipykernel_9668\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Hobbyist           1.0
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code      NaN
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession      NaN
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN      NaN
# 88802                                                     NaN      NaN
# 88816                                                     NaN      NaN
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# to make sure that i understand the convert nan values

# %%
df["YearsCode"]
# Out:
# Respondent
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 88377   NaN
# 88601   NaN
# 88802   NaN
# 88816   NaN
# 88863   NaN
# Name: YearsCode, Length: 88883, dtype: float64

# %%
 # when we want to calculate the mean an error will appear
df["YearsCode"].mean()
 # because this column has nan values 
 # we need to convert it
# Out:
# nan

# %%
 # converting the column to float
df["YearsCode"]=df["YearsCode"].astype(float)
 # an error
 # let's read the error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Eman\Desktop\data\pandas\pandas project\pandas project.ipynb Cell 39 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Eman/Desktop/data/pandas/pandas%20project/pandas%20project.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> df["YearsCode"]=df["YearsCode"].astype(float)
#
# File c:\Users\Eman\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
# ...

# %% [markdown]
# could not convert string to float: 'Less than 1 year'

# %% [markdown]
# let's show the column using unique function

# %%
df['YearsCode'].unique()
# Out:
# array([nan])

# %% [markdown]
# let's replace 'Less than 1 year' and 'More than 50 years' with zero

# %%
df['YearsCode'].replace('Less than 1 year',0, inplace=True)

# %%
df['YearsCode'].replace('More than 50 year',51, inplace=True)

# %%
df['YearsCode']=df["YearsCode"].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# nan
